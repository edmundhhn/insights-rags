# %% [markdown]
# # Web Scrapers

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %% [markdown]
# ## Sraper for news about China

# %%
def scrape_china():
    # Define the URL for the region-specific page
    url = 'https://thediplomat.com/regions/east-asia/'
    
    # Set up headers to mimic a browser request
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    }
    
    # Send a GET request to the page
    response = requests.get(url, headers=headers)
    
    # Check for successful request
    if response.status_code == 200:
        # Parse the page content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all article blocks - Adjust this based on the site's HTML structure
        articles = soup.find_all('a', class_='td-post')
    
        # Extract titles, links, and summaries
        article_data = []
        for article in articles:
            link = article['href']
            title_tag = article.find('h4')
            if title_tag and link:
                title = title_tag.text.strip()
                #link = title_tag.find('a')['href']
                #summary = article.find('p').text.strip() if article.find('p') else ''
                full_link = 'https://thediplomat.com' + link
    
                # scrape the article 
                response_article = requests.get(full_link, headers=headers)
    
                if response.status_code == 200:
                    soup_article = BeautifulSoup(response_article.content, 'html.parser')
                    content = ""
                    section = soup_article.find("section", id="tda-gated-body")
                    # print(section)
                    paragraphs = section.find_all("p")
                    for para in paragraphs:
                        content += para.text.strip() + '\n'
                
                
                article_data.append({'title':title, 'link':full_link, 'content':content})
                #article_data.append({'title': title, 'link': full_link, 'summary': summary})
    
        # Save to a DataFrame
        df = pd.DataFrame(article_data)
        #print(df)
    
        # Optional: Save to a CSV file
        df.to_csv('data/china.csv', index=False)
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")

    return df

df_china = scrape_china()

# %%
df_china.head()
# Out:
#                                                title  \
# 0  First Known Survivor of China’s Forced Organ H...
# 1  China Hits Back at the US in Response to Dopin...
# 2  SEATO’s 70th Anniversary: Lessons for Asia’s E...
# 3  Nagasaki’s Atomic Bomb Commemoration Overshado...
# 4             Japan Issues First ‘Megaquake’ Warning
#
#                                                 link  \
# 0  https://thediplomat.com/2024/08/first-known-su...
# 1  https://thediplomat.com/2024/08/china-hits-bac...
# 2  https://thediplomat.com/2024/08/seatos-70th-an...
# 3  https://thediplomat.com/2024/08/nagasakis-atom...
# 4  https://thediplomat.com/2024/08/japan-issues-f...
#
#                                              content
# 0  In a chilling revelation that underscores the ...
# 1  China is trying to fight fire with fire in the...
# 2  September 2024 marks the 70th anniversary of t...
# 3  For the Japanese, August is a special month. T...
# 4  Japanese Prime Minister Kishida Fumio canceled...

# %% [markdown]
# ## Scraper for News About Retail

# %%
response = requests.get('https://chainstoreage.com/market-segment/retail/discount-store')

# %%
def scrape_retail():
    # Define the URL for the region-specific page
    url = 'https://chainstoreage.com/market-segment/retail/discount-store'
    
    # Set up headers to mimic a browser request
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    }
    
    # Send a GET request to the page
    response = requests.get(url, headers=headers)
    
    # Check for successful request
    if response.status_code == 200:
        # Parse the page content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all article blocks - Adjust this based on the site's HTML structure
        articles = soup.find_all('a', class_=['astro-hh3v2ni7','heading__link'])
    
        # Extract titles, links, and summaries
        article_data = []
        for article in articles:
            link = article['href']
            if "heading__link" in article["class"]:
                title_tag = article
            else:
                title_tag = article.find('h3')
            if title_tag and link:
                title = title_tag.text.strip()
                #link = title_tag.find('a')['href']
                #summary = article.find('p').text.strip() if article.find('p') else ''
                full_link = 'https://chainstoreage.com' + link
    
                # scrape the article 
                response_article = requests.get(full_link, headers=headers)
    
                
                if response.status_code == 200:
                    soup_article = BeautifulSoup(response_article.content, 'html.parser')
                    content = ""
                    section = soup_article.find("article", class_="content")
                    # print(section)
                    paragraphs = section.find_all(["p", "ul"])
                    #print(paragraphs)
                    for para in paragraphs:
                        content += para.text.strip() + '\n'
                
                
                article_data.append({'title':title, 'link':full_link, 'content':content})
                #article_data.append({'title': title, 'link': full_link, 'summary': summary})
    
        # Save to a DataFrame
        df_retail = pd.DataFrame(article_data)
        #print(df)
    
        # Optional: Save to a CSV file
        df_retail.to_csv('data/retail.csv', index=False)
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
    return df_retail

# %%
df_retail
# Out:
#                                                 title  \
# 0   Walmart breaks record with Q2 online grocery s...
# 1   Walmart Inc. is more dominant in the U.S. onli...
# 2   Big Lots closing about 300 stores; California ...
# 3   Big Lots is shrinking its brick-and-mortar foo...
# 4   Dollar General launches omnichannel back-to-sc...
# 5   Family Dollar optimizes assortment with predic...
# 6   Target lauches back-to-school personalization ...
# 7   Walmart creates metaverse shop for college stu...
# 8   Walmart targets food waste with in-store 'depa...
# 9   Ollie's to launch its first-ever credit card —...
# 10  Humana to open primary care centers for senior...
# 11  Walmart prices thousands of back-to-school ite...
#
#                                                  link  \
# 0   https://chainstoreage.com/walmart-breaks-recor...
# 1   https://chainstoreage.com/walmart-breaks-recor...
# 2   https://chainstoreage.com/big-lots-closing-abo...
# 3   https://chainstoreage.com/big-lots-closing-abo...
# 4   https://chainstoreage.com/dollar-general-launc...
# 5   https://chainstoreage.com/family-dollar-optimi...
# 6   https://chainstoreage.com/target-lauches-back-...
# 7   https://chainstoreage.com/walmart-creates-meta...
# 8   https://chainstoreage.com/walmart-targets-food...
# 9   https://chainstoreage.com/ollies-launch-its-fi...
# 10  https://chainstoreage.com/humana-open-primary-...
# 11  https://chainstoreage.com/walmart-prices-thous...
#
#                                               content
# 0   facebooktwitterlinkedInemail\nWalmart Inc. is ...
# 1   facebooktwitterlinkedInemail\nWalmart Inc. is ...
# 2   facebooktwitterlinkedInemail\nBig Lots is down...
# 3   facebooktwitterlinkedInemail\nBig Lots is down...
# 4   facebooktwitterlinkedInemail\nDollar General i...
# 5   facebooktwitterlinkedInemail\nFamily Dollar is...
# 6   facebooktwitterlinkedInemail\nTarget Corp. is ...
# 7   facebooktwitterlinkedInemail\nWalmart is expan...
# 8   facebooktwitterlinkedInemail\nWalmart Inc. is ...
# 9   facebooktwitterlinkedInemail\nThe country's la...
# 10  facebooktwitterlinkedInemail\nSome of the spac...
# 11  facebooktwitterlinkedInemail\nWalmart is aggre...

# %% [markdown]
# ## Scraper for Market News

# %%
response = requests.get('https://www.fool.com/investing/2024/08/11/down-79-this-growth-stock-could-double-in-the-hous/')

# %%
def scrape_market():
    # Define the URL for the region-specific page
    url = 'https://www.fool.com/investing-news/'
    
    # Set up headers to mimic a browser request
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3',
    }
    
    # Send a GET request to the page
    response = requests.get(url, headers=headers)
    
    # Check for successful request
    if response.status_code == 200:
        # Parse the page content
        soup = BeautifulSoup(response.content, 'html.parser')
        
        # Find all article blocks - Adjust this based on the site's HTML structure
        articles = soup.find_all('a', class_='text-gray-1100')
    
        # Extract titles, links, and summaries
        article_data = []
        for article in articles[:15]:
            link = article['href']
            title_tag = article.find('h5')
            if title_tag and link:
                title = title_tag.text.strip()
                #link = title_tag.find('a')['href']
                #summary = article.find('p').text.strip() if article.find('p') else ''
                full_link = 'https://www.fool.com' + link
    
                # scrape the article 
                response_article = requests.get(full_link, headers=headers)
                
                if response.status_code == 200:
                    soup_article = BeautifulSoup(response_article.content, 'html.parser')
                    content = ""
                    section = soup_article.find_all("div", class_="foolcom-grid-content-sidebar")
                    if len(section) == 2:
                        section = section[1]
                    elif len(section) == 1:
                        section = section[0]
                    else:
                        continue
                    # print(section)
                    paragraphs = section.find_all(["p", "ul"])
                    #print(paragraphs)
                    for para in paragraphs:
                        content += para.text.strip() + '\n'
                
                
                article_data.append({'title':title, 'link':full_link, 'content':content})
                #article_data.append({'title': title, 'link': full_link, 'summary': summary})
    
        # Save to a DataFrame
        df_market = pd.DataFrame(article_data)
        #print(df)
    
        # Optional: Save to a CSV file
        df_market.to_csv('data/market.csv', index=False)
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")
    return df_market

# %%
df_market
# Out:
#                                                 title  \
# 0   Down 79%, This Growth Stock Could Double in th...
# 1   Down 54%, Is It Time to Buy the Dip on This Gr...
# 2   Down Between 12% and 24% From Their 52-Week Hi...
# 3   Down 79%, This Growth Stock Could Double in th...
# 4   Is Now the Time to Buy the 2 Worst-Performing ...
# 5   Prediction: 1 Top Artificial Intelligence (AI)...
# 6              Where Will Amazon Stock Be in 3 Years?
# 7   Market Sell-Off: Is It Time to Buy the Dip on ...
# 8   Elon Musk Just Said Tesla Has a $200 Trillion ...
# 9   Mark Zuckerberg Has a Bold Vision for Meta's C...
# 10  Down 54%, Is It Time to Buy the Dip on This Gr...
# 11  Should Apple Acquire Peloton in 2024? 2 Things...
# 12  How Much Will Lockheed Martin Pay Out in Divid...
# 13  Down Between 12% and 24% From Their 52-Week Hi...
#
#                                                  link  \
# 0   https://www.fool.com/investing/2024/08/11/down...
# 1   https://www.fool.com/investing/2024/08/11/down...
# 2   https://www.fool.com/investing/2024/08/11/down...
# 3   https://www.fool.com/investing/2024/08/11/down...
# 4   https://www.fool.com/investing/2024/08/11/is-n...
# 5   https://www.fool.com/investing/2024/08/11/pred...
# 6   https://www.fool.com/investing/2024/08/11/wher...
# 7   https://www.fool.com/investing/2024/08/11/mark...
# 8   https://www.fool.com/investing/2024/08/11/elon...
# 9   https://www.fool.com/investing/2024/08/11/mark...
# 10  https://www.fool.com/investing/2024/08/11/down...
# 11  https://www.fool.com/investing/2024/08/11/appl...
# 12  https://www.fool.com/investing/2024/08/11/how-...
# 13  https://www.fool.com/investing/2024/08/11/down...
#
#                                               content
# 0   A recovery in the housing market could help re...
# 1   GXO Logistics slipped on its earnings report. ...
# 2   Buying excellent companies when they are out o...
# 3   A recovery in the housing market could help re...
# 4   One of these stocks is a seemingly more promis...
# 5   A couple of solid AI-related growth opportunit...
# 6   Can this tech conglomerate hold on to its loft...
# 7   Investors might want to take advantage of the ...
# 8   Tesla's next big opportunity has nothing to do...
# 9   Artificial intelligence could enhance Meta's e...
# 10  GXO Logistics slipped on its earnings report. ...
# 11  The tech titan would be Peloton's white knight...
# 12  The defense company has increased its dividend...
# 13  Buying excellent companies when they are out o...
